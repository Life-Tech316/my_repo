# %%
import scipy.stats as st
n, m, s = 40, 160, 10
rg = st.norm(m, s)
data = rg.rvs(n)
print(data)
# Out:
# [159.89521387 159.72315412 164.59225037 148.22062383 171.60362826
#  159.57198814 164.67434232 145.6065877  163.42732857 170.78024434
#  166.97816499 163.25358879 167.21231772 160.21460408 161.04023051
#  169.029501   163.98331403 168.17593721 153.17848899 175.09931587
#  148.49286684 142.20676252 161.60696984 152.60447649 162.35042492
#  152.7112886  170.79895026 170.05686003 177.60742265 150.3805591
#  156.98553785 157.21565226 177.93483131 177.0039978  160.53544661
#  153.5718014  150.99885411 158.82549522 166.88589022 158.41413998]

# %%
import numpy as np
n, m, s = 40, 160, 10
data = np.random.randn(n) * s + m
print(data)
# Out:
# [148.12780139 168.01216196 148.23446662 155.32675586 148.05065945
#  159.43006187 165.10912508 165.0138198  152.07058005 153.65765866
#  152.06649782 156.78698573 152.22269557 149.3927349  171.97693648
#  147.63327198 161.52896079 156.71326284 168.61463167 158.29273458
#  168.87685377 167.31560371 158.52667799 153.43750082 160.40955791
#  168.46703355 150.55649914 152.38031388 154.47631465 179.84394774
#  162.51930522 160.35452955 157.01120859 166.42170552 152.65154183
#  162.85046028 176.87826796 155.46316016 150.49025835 170.54677317]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("ggplot")
c, x, _ = plt.hist(data, 10)

# %%
print(c)
print(x)
# Out:
# [ 3.  4.  7.  6.  3.  5.  2.  3.  4.  3.]
# [ 140.27741556  144.10226567  147.92711579  151.7519659   155.57681601
#   159.40166613  163.22651624  167.05136635  170.87621647  174.70106658
#   178.52591669]

# %%
rg1 = st.norm(165, 10)
rg2 = st.norm(160, 12)

data1 = rg1.rvs(40)
data2 = rg2.rvs(70)

# %%
fig, axes = plt.subplots(nrows=2)
axes[0].hist(data1)
axes[1].hist(data2)
# Out:
# (array([  4.,   0.,   7.,   9.,  12.,  12.,  16.,   8.,   1.,   1.]),
#  array([ 134.39646263,  139.62090105,  144.84533948,  150.0697779 ,
#          155.29421633,  160.51865475,  165.74309318,  170.9675316 ,
#          176.19197003,  181.41640846,  186.64084688]),
#  <a list of 10 Patch objects>)

# %%
fig, axes = plt.subplots(nrows=2)
axes[0].hist(data1, range=(140, 180), normed=True)
axes[1].hist(data2, range=(140, 180), normed=True)
# Out:
# (array([ 0.        ,  0.00769231,  0.02692308,  0.03076923,  0.03461538,
#          0.03461538,  0.05      ,  0.03846154,  0.02307692,  0.00384615]),
#  array([ 140.,  144.,  148.,  152.,  156.,  160.,  164.,  168.,  172.,
#          176.,  180.]),
#  <a list of 10 Patch objects>)

# %%
kde1 = st.gaussian_kde(data1)
kde2 = st.gaussian_kde(data2)
plot_x = np.linspace(140, 180, 100)
density1 = kde1(plot_x)
density2 = kde2(plot_x)

fig, axes = plt.subplots(nrows=2)
axes[0].hist(data1, 20, range=(130, 200), normed=True)
axes[0].plot(plot_x, density1)
axes[1].hist(data2, 20, range=(130, 200), normed=True)
axes[1].plot(plot_x, density2)

# %%
plt.fill(plot_x, density1, alpha=0.5, label="class1")
plt.fill(plot_x, density2, alpha=0.5, label="class2")
plt.legend()

# %%
import matplotlib.pyplot as plt
temper1 = st.norm(25, 0.5).rvs(30)
temper2 = st.norm(25, 0.5).rvs(30)
kde1 = st.gaussian_kde(temper1)
kde2 = st.gaussian_kde(temper2)
plot_x = np.linspace(23, 29, 100)
temper1
density1 = kde1(plot_x)
density2 = kde2(plot_x)
plt.fill(plot_x, density1, alpha=0.5, label="temper1")
plt.fill(plot_x, density2, alpha=0.5, label="temper1")

# %%
kde1 = st.gaussian_kde(temper1)
kde2 = st.gaussian_kde(temper2)
plot_x = np.linspace(23, 29, 100)

density1 = kde1(plot_x)
density2 = kde2(plot_x)

plt.fill(plot_x, density1, alpha=0.5, label="temper1")
plt.fill(plot_x, density2, alpha=0.5, label="temper2")
plt.legend()

# %%
result = st.ttest_ind(temper1, temper2, equal_var=False)
print(result.pvalue)
# Out:
# 0.43611778940945967

# %%
result = st.ttest_ind(data1, data2, equal_var=False)
print(result.pvalue)
# Out:
# 0.006582467979929133
# 0.017466425257441968

# %%
result = st.mannwhitneyu(data1, data2)
print(result.pvalue)
# Out:
# 0.017466425257441968

# %%
dat = np.loadtxt("chapter_4_anova_1.dat")
kdes = [st.gaussian_kde(dat[i, :]) for i in range(dat.shape[0])]

plot_x = np.linspace(40, 100, 20)
densities = [print(kde(plot_x)) or kde(plot_x) for kde in kdes]


for i in range(dat.shape[0]):
    plt.plot(plot_x, densities[i], linewidth=4, label=i)
plt.legend()
# Out:
# [0.00141764 0.00330427 0.00631693 0.01037685 0.01520017 0.0200949
#  0.0238935  0.02584893 0.02675076 0.02831459 0.03081482 0.0318786
#  0.02873147 0.02160577 0.01386263 0.00865153 0.00632812 0.00518869
#  0.00383026 0.00223054]
# [2.21498303e-03 5.18918961e-03 1.00305333e-02 1.60366071e-02
#  2.05158136e-02 2.21385621e-02 2.45582782e-02 3.12243139e-02
#  3.87269421e-02 4.07182134e-02 3.57385882e-02 2.74278614e-02
#  1.93042257e-02 1.22372233e-02 6.38555076e-03 2.48747719e-03
#  6.76222250e-04 1.23357185e-04 1.47746432e-05 1.14788050e-06]
# [0.00211053 0.00252731 0.00245079 0.00272778 0.00472182 0.00928645
#  0.01595367 0.02303141 0.02881794 0.03270463 0.03465663 0.0341554
#  0.03086715 0.02587913 0.02080321 0.01615989 0.01175339 0.00775215
#  0.00455259 0.00230963]
# [3.11197606e-08 8.49198655e-07 1.43611724e-05 1.51118210e-04
#  9.96489344e-04 4.17338071e-03 1.14006361e-02 2.14021405e-02
#  3.01969265e-02 3.58317271e-02 3.88856723e-02 3.95338629e-02
#  3.67402688e-02 2.99721020e-02 2.12506073e-02 1.43360546e-02
#  1.12539200e-02 9.68146135e-03 6.66962499e-03 3.08292095e-03]

# %%
print(dat[0],dat[1])
pvalue = st.f_oneway(*dat)
print(pvalue)
# Out:
# [92. 76. 75. 60. 82. 63. 48. 54. 70. 51. 62. 74. 75. 71. 78. 78. 58. 67.
#  68. 77. 74. 60. 79. 63. 64. 74. 57. 78. 94. 57.] [53. 65. 69. 65. 70. 50. 71. 60. 70. 72. 75. 45. 66. 72. 52. 80. 68. 66.
#  66. 64. 55. 53. 69. 57. 63. 77. 81. 53. 76. 64.]
# F_onewayResult(statistic=5.845972666882928, pvalue=0.0009380446913126313)
